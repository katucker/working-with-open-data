# %% [markdown]
# Openly-shared data is often published in distinct chunks, such as annual summaries of data points with each year's summary published in a separate file. In order to facilitate trend analysis on data published in that fashion, the distinct chunks can be combined.
#
# This notebook shows an example of retrieving multiple data files, using an Application Programming Interface (API), and combining the data in those files in a single Pandas dataframe. The example shows some of the common issues encountered when using open data.
#
# The data used in the example are available through the U.S. Department of Education's Open Data Platform, at https://data.ed.gov. That system organizes datasets in "data profiles" that describe sets of related data files.
# The specific dataset used in the example is the collection of data files in the data profile with title "IDEA Section 618 Data Products: Static Tables Part B Maintenance of Effort Reduction Table 5".
#
# Searching on that title on the Open Data Platform leads to a page which should look like the [IDEA Data Profile](IDEA-data-profile.png) image. Selecting the "Resources" link on that page presents a list of data files, each corresponding to a single school year. This example notebook shows how to retrieve all of the data files in that list and combine them in a way that enables trend analysis over all the school years for which data are available.
#
# The Open Data Platform has an API, described in a link at the bottom right of the web application's footer. At the time of this notebook's creation, the API is documented at [CKAN version 2.9 API](http://docs.ckan.org/en/2.9/api/).
#
# This example uses a Python module specific to the CKAN API. That Python module implements a "wrapper" around the lower-level networking modules, making it somewhat easier to use the API by abstracting some of the conventions used in the CKAN API. The Python code to use the API thus must import that CKAN API module. **NOTE:** The CKAN API module is typically not included by default in Python library sets, so it may need to be installed in order to run this notebook.

# %%
# Import the CKAN API wrapper module.
import ckanapi

# %% [markdown]
# The CKAN API documentation notes that responses to API calls are formatted as JSON documents. The json module will help display those responses.

# %%
import json

# %% [markdown]
# Make an API call to retrieve a list of data files.
#
# The CKAN API uses the term "package" for what the Open Data Platform calls data profiles. The API funtion named "package_show" returns all the metadata describing a package. That API call needs just one parameter - a unique identifier for the package.
#
# The Open Data Platform lists the unique identifer for the package in this example as "cf9bff75-1577-4ca7-a957-1f0c269aeff4". (The "Show more" link may need to be selected to show the unique identifier.)
#
# The following Python code performs the package_show API function call for the specific data profile of interest, and displays the result in a readable format.

# %%
# Define the parameters for the API connection.
# The required parameter for the connection is the base URL for the API functions.
# For this example, use the U.S. Department of Education's data portal at data.ed.gov.
# The CKAN API wrapper module appends any other information to the URL specific to the API version.
CKAN_BASE_URL = "https://data.ed.gov"

# Create a connection object for using the API.
remote = ckanapi.RemoteCKAN(CKAN_BASE_URL)

# Use the API call to retrieve the descriptive metadata for a "package", using the unique identifer
# in the data portal that contains them all.
IDENTIFIER = "cf9bff75-1577-4ca7-a957-1f0c269aeff4"

# Construct a dictionary object containing the parameters to use for the API call.
# For this example, the only parameter needed is the ID.
params = {'id': IDENTIFIER}

# Use the connection object to perform the API call, passing the name of the function to invoke and the parameter
# dictionary.
result = remote.call_action(action = 'package_show', data_dict = params)

# Print the response to see what the API returns. 
# Knowing it's a JSON object, format it for easier reading with the json.dumps function.
print(json.dumps(result,indent=2))
# Out:
# {
#   "access_level": "public",
#   "amended_by_user": "true",
#   "author": "Office of Special Education Programs - Research to Practice Division",
#   "author_email": "OSEPideadata@ed.gov",
#   "bureau_code": "018:20",
#   "creator_user_id": "d6645315-1307-4d3a-9295-2a4f21b3a7ac",
#   "data_dictionary_pkg": "",
#   "data_dictionary_pkg_format": "",
#   "data_quality": false,
#   "end_date": "",
#   "id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#   "indraft": "false",
#   "isopen": true,
#   "level_of_data": [
#     "national"
#   ],
#   "license_id": "cc-zero",
#   "license_title": "Creative Commons CCZero",
#   "license_url": "http://www.opendefinition.org/licenses/cc-zero",
#   "maintainer": "",
#   "maintainer_email": "odp@ed.gov",
#   "metadata_created": "2021-09-24T14:30:08.358273",
#   "metadata_modified": "2023-03-15T13:31:15.083103",
#   "name": "idea-section-618-data-products-static-tables-part-b-moe-table5",
#   "notes": "IDEA Section 618 Data Products: Static Tables\r\n##Part B Maintenance of Effort Reduction and Coordinated Early Intervening Services\r\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services",
#   "num_resources": 8,
#   "num_tags": 12,
#   "organization": {
#     "id": "b155e7a9-48f7-4edd-863d-896d48d84367",
#     "name": "osep",
#     "title": "Office of Special Education Programs (OSEP)",
#     "type": "organization",
#     "description": "",
#     "image_url": "",
#     "created": "2021-02-27T10:30:21.776574",
#     "is_organization": true,
#     "approval_status": "approved",
#     "state": "active"
#   },
#   "owner_org": "b155e7a9-48f7-4edd-863d-896d48d84367",
#   "owner_suborg": "",
#   "primary_it_investment_uii": "",
#   "private": false,
#   "program_code": "018:000",
#   "record_schedule": "None",
#   "resource_index": "",
#   "resources_indraft": "",
#   "rights": "",
#   "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/index.html",
#   "spatial": [
#     "United States"
#   ],
#   "start_date": "",
#   "state": "active",
#   "system_of_records": "",
#   "title": "IDEA Section 618 Data Products: Static Tables Part B Maintenance of Effort Reduction Table 5",
#   "type": "dataset",
#   "update_frequency": "",
#   "url": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/index.html",
#   "version": null,
#   "extras": [
#     {
#       "key": "catalog_@context",
#       "value": "https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld"
#     },
#     {
#       "key": "catalog_@id",
#       "value": "osep_data_json"
#     },
#     {
#       "key": "catalog_conformsTo",
#       "value": "https://project-open-data.cio.gov/v1.1/schema"
#     },
#     {
#       "key": "catalog_describedBy",
#       "value": "https://project-open-data.cio.gov/v1.1/schema/catalog.json"
#     },
#     {
#       "key": "harvest_object_id",
#       "value": "be0c86a4-e48c-4c82-b99e-b7af98298fb7"
#     },
#     {
#       "key": "harvest_source_id",
#       "value": "f26fede9-adbe-4798-92c1-4052cd3e5547"
#     },
#     {
#       "key": "harvest_source_title",
#       "value": "IDEA Section 618 ingest"
#     },
#     {
#       "key": "identifier",
#       "value": "idea-section-618-data-products-static-tables-part-b-moe-table5"
#     },
#     {
#       "key": "modified",
#       "value": "2021-01-28"
#     },
#     {
#       "key": "resource-type",
#       "value": "Dataset"
#     },
#     {
#       "key": "source_datajson_identifier",
#       "value": "true"
#     },
#     {
#       "key": "source_hash",
#       "value": "ba19ce83f1ea93eb544c0833d30b17f3b8553272"
#     },
#     {
#       "key": "source_schema_version",
#       "value": "1.1"
#     }
#   ],
#   "relationships_as_subject": [
#     {
#       "__extras": {
#         "subject_package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#         "object_package_id": "04e9d91e-31fe-4557-b924-fbe3775dcb8f"
#       },
#       "comment": "",
#       "id": "4b643b79-22bf-43f5-9c42-8c21123700fc",
#       "type": "child_of"
#     }
#   ],
#   "resources": [
#     {
#       "access_url": "",
#       "api_url": "",
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2023-02-17T16:27:52.493380",
#       "data-dictionary-format": "",
#       "data_dictionary_res": "",
#       "data_dictionary_res_file": "",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "Table 5 Number of children who received CEIS anytime in the past two years and who received special education and related services 2020-2021",
#       "ed_source": "",
#       "field-clear-data-dict": "",
#       "format": "XLSX",
#       "hash": "",
#       "id": "1f5632da-5044-4de6-a81c-51485434ef0c",
#       "last_modified": "2023-02-17T16:27:51.897332",
#       "metadata_modified": "2023-03-15T13:31:15.090648",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2020-2021",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 0,
#       "resource_set": "downloadable",
#       "resource_type": null,
#       "size": 26854,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/1f5632da-5044-4de6-a81c-51485434ef0c/download/2021-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "access_url": "",
#       "api_url": "",
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2022-02-02T16:17:27.129246",
#       "data-dictionary-format": "",
#       "data_dictionary_res": "",
#       "data_dictionary_res_file": "",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\r\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\r\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\r\n2019-2020",
#       "ed_source": "",
#       "field-clear-data-dict": "",
#       "format": "XLSX",
#       "hash": "",
#       "id": "97aac191-f354-4268-9c66-f8412c1009d3",
#       "last_modified": "2022-02-08T18:55:00.641641",
#       "metadata_modified": "2023-02-17T16:27:52.068419",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2019-2020",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 1,
#       "resource_set": "downloadable",
#       "resource_type": null,
#       "size": 26876,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/97aac191-f354-4268-9c66-f8412c1009d3/download/1920-bmaintenancedistrict-05.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2021-09-24T14:30:08.377008",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\n2018-2019",
#       "format": "XLSX",
#       "hash": "",
#       "id": "0e5691e1-7994-4c2c-8a6f-9168b0a2e02f",
#       "last_modified": "2021-09-25T22:37:24.035263",
#       "metadata_modified": "2023-02-17T16:27:52.069119",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2018-2019",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 2,
#       "resource_type": null,
#       "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/2018-2019/part-b/ceis-and-moe/1819-bmaintenancedistrict-5.xlsx",
#       "size": 29301,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/0e5691e1-7994-4c2c-8a6f-9168b0a2e02f/download/1819-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2021-09-24T14:30:08.377016",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\n2017-2018",
#       "format": "XLSX",
#       "hash": "",
#       "id": "54df1fca-8d76-4289-b0a7-af6de4d6b6c0",
#       "last_modified": "2021-09-25T22:37:26.030776",
#       "metadata_modified": "2023-02-17T16:27:52.069447",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2017-2018",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 3,
#       "resource_type": null,
#       "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/2017-2018/part-b/ceis-and-moe/1718-bmaintenancedistrict-5.xlsx",
#       "size": 26566,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/54df1fca-8d76-4289-b0a7-af6de4d6b6c0/download/1718-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2021-09-24T14:30:08.377018",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\n2016-2017",
#       "format": "XLSX",
#       "hash": "",
#       "id": "d1810070-5cb3-4ff8-ac4d-d77f96648ac7",
#       "last_modified": "2021-09-25T22:37:28.001606",
#       "metadata_modified": "2023-02-17T16:27:52.069708",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2016-2017",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 4,
#       "resource_type": null,
#       "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/2016-2017/part-b/ceis-and-moe/1617-bmaintenancedistrict-5.xlsx",
#       "size": 28181,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/d1810070-5cb3-4ff8-ac4d-d77f96648ac7/download/1617-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2021-09-24T14:30:08.377021",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\n2015-2016",
#       "format": "XLSX",
#       "hash": "",
#       "id": "6e51e251-3f3e-4a9a-ad22-83935913b204",
#       "last_modified": "2021-09-25T22:37:30.123373",
#       "metadata_modified": "2023-02-17T16:27:52.069996",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2015-2016",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 5,
#       "resource_type": null,
#       "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/2015-2016/part-b/ceis-and-moe/1516-bmaintenancedistrict-5.xlsx",
#       "size": 23667,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/6e51e251-3f3e-4a9a-ad22-83935913b204/download/1516-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2021-09-24T14:30:08.377023",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\n2014-2015",
#       "format": "XLSX",
#       "hash": "",
#       "id": "e6c2b634-d68f-48ac-b1a6-0665f97a64f6",
#       "last_modified": "2021-09-25T22:37:32.036937",
#       "metadata_modified": "2023-02-17T16:27:52.070319",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2014-2015",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 6,
#       "resource_type": null,
#       "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/2014-2015/part-b/ceis-and-moe/1415-bmaintenancedistrict-5.xlsx",
#       "size": 24818,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/e6c2b634-d68f-48ac-b1a6-0665f97a64f6/download/1415-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     },
#     {
#       "approval_status": "approved",
#       "cache_last_updated": null,
#       "cache_url": null,
#       "created": "2021-09-24T14:30:08.377025",
#       "data_dictionary_res_format": "",
#       "datastore_active": false,
#       "datastore_contains_all_records_of_source_file": false,
#       "description": "#IDEA Section 618 Data Products: Static Tables\n##Part B - Maintenance of Effort Reduction and Coordinated Early Intervening Services\nTable 5 Number of children who received CEIS anytime in the past two years and who received special education and related services\n2013-2014",
#       "format": "XLSX",
#       "hash": "",
#       "id": "d079f2a2-5827-4b8d-a768-2dc1590bc346",
#       "last_modified": "2021-09-25T22:37:33.980927",
#       "metadata_modified": "2023-02-17T16:27:52.070460",
#       "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#       "mimetype_inner": null,
#       "name": "2013-2014",
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
#       "position": 7,
#       "resource_type": null,
#       "scraped_from": "https://www2.ed.gov/programs/osepidea/618-data/static-tables/2013-2014/part-b/ceis-and-moe/1314-bmaintenancedistrict-5.xlsx",
#       "size": 15717,
#       "state": "active",
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/d079f2a2-5827-4b8d-a768-2dc1590bc346/download/1314-bmaintenancedistrict-5.xlsx",
#       "url_type": "upload"
#     }
#   ],
#   "tags": [
#     {
#       "display_name": "United States",
#       "id": "9b098863-0559-48d5-85d1-4feb97847b57",
#       "name": "United States",
#       "state": "active",
#       "vocabulary_id": "bb12e0a0-bafa-4239-9ee8-adda3ad57824"
#     },
#     {
#       "display_name": "ceis",
#       "id": "bad73695-1616-418b-bfe2-82b1470a0760",
#       "name": "ceis",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "coordinated-early-intervening-services",
#       "id": "98228d11-c1d1-4916-845d-d85d232a891b",
#       "name": "coordinated-early-intervening-services",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "data-products",
#       "id": "44d42bb1-2b22-4798-b6cb-5a5d724bb591",
#       "name": "data-products",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "individuals-with-disabilities-education-act",
#       "id": "516c188e-c150-4a9b-a041-361e0a5637ad",
#       "name": "individuals-with-disabilities-education-act",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "maintenance-of-effort",
#       "id": "f9548cae-a7c2-449d-b2cb-7aecb6493712",
#       "name": "maintenance-of-effort",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "national",
#       "id": "21e7d1d4-cf1b-49ec-b41b-e0396fb0bcba",
#       "name": "national",
#       "state": "active",
#       "vocabulary_id": "9199913c-5e81-4432-8809-3743a987787a"
#     },
#     {
#       "display_name": "part-b",
#       "id": "98933b57-03df-42f8-ad5c-a290d278ba94",
#       "name": "part-b",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "performance",
#       "id": "f0a891e5-f56b-430a-872c-73209477dee3",
#       "name": "performance",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "section-618",
#       "id": "0613567d-90fc-4e21-baef-9c0bd8bc08fa",
#       "name": "section-618",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "special-education",
#       "id": "da967e6b-4f41-4fe3-b91a-bc69090950aa",
#       "name": "special-education",
#       "state": "active",
#       "vocabulary_id": null
#     },
#     {
#       "display_name": "static-tables",
#       "id": "421ba11f-5a9b-4e21-aa47-fe58d6715fe9",
#       "name": "static-tables",
#       "state": "active",
#       "vocabulary_id": null
#     }
#   ],
#   "groups": [],
#   "relationships_as_object": []
# }

# %% [markdown]
# The "resources" key contains a list of descriptive information about the data files associated with the package, similar to the partial set of key/value pairs below.
# ~~~
# "resources": [
#     {
#       "access_url": "",
# ...
#       "description": "Table 5 Number of children who received CEIS anytime in the past two years and who received special education and related services 2020-2021",
#       "ed_source": "",
# ...
#       "package_id": "cf9bff75-1577-4ca7-a957-1f0c269aeff4",
# ...
#       "url": "https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/1f5632da-5044-4de6-a81c-51485434ef0c/download/2021-bmaintenancedistrict-5.xlsx",
# ...
#     },
# ~~~
#
#  The "url" key in each resources entry is a web address for where the data file is stored. Examine the URLs.

# %%
datafile_list = result.get('resources',None)
if datafile_list is not None:
    for datafile in datafile_list:
        url = datafile.get('url',None)
        if url is not None:
            print(url)
# Out:
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/1f5632da-5044-4de6-a81c-51485434ef0c/download/2021-bmaintenancedistrict-5.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/97aac191-f354-4268-9c66-f8412c1009d3/download/1920-bmaintenancedistrict-05.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/0e5691e1-7994-4c2c-8a6f-9168b0a2e02f/download/1819-bmaintenancedistrict-5.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/54df1fca-8d76-4289-b0a7-af6de4d6b6c0/download/1718-bmaintenancedistrict-5.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/d1810070-5cb3-4ff8-ac4d-d77f96648ac7/download/1617-bmaintenancedistrict-5.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/6e51e251-3f3e-4a9a-ad22-83935913b204/download/1516-bmaintenancedistrict-5.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/e6c2b634-d68f-48ac-b1a6-0665f97a64f6/download/1415-bmaintenancedistrict-5.xlsx
# https://data.ed.gov/dataset/cf9bff75-1577-4ca7-a957-1f0c269aeff4/resource/d079f2a2-5827-4b8d-a768-2dc1590bc346/download/1314-bmaintenancedistrict-5.xlsx

# %% [markdown]
# The URLs all end in a file name with the Excel workbook file extension. Try loading them into a pandas dataframe using the read_excel function and examining the first few lines in each. Note, the URL can be used directly by read_excel.

# %%
import pandas as pd

len(datafile_list)
# Out:
# 8

# %%
url = datafile_list[0].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2020-21
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2022-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                143
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                  +
# 9                                                248
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                                  +
# 9                                                543

# %%
url = datafile_list[1].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2019-20
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2021-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                142
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                  +
# 9                                                452
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                                  +
# 9                                                694

# %%
url = datafile_list[2].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2018-19
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2020-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                139
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                  +
# 9                                               1214
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                                  +
# 9                                                868

# %%
url = datafile_list[3].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2017-18
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2019-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                138
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                 50
# 9                                               1020
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                               1768
# 9                                                586

# %%
url = datafile_list[5].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2015-16
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2017-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                137
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                802
# 9                                                747
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                                178
# 9                                                856

# %%
url = datafile_list[6].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2014-15
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2016-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                136
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                866
# 9                                               1033
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                                575
# 9                                                865

# %%
url = datafile_list[7].get('url')
df = pd.read_excel(url)
df.head(10)
# Out:
#                                     Table Identifier  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                               bmaintenancedistrict_5  \
# 0                                            2013-14
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2016-01-12 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                135
# 9                                                 54
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                               2399
# 9                                               1301
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS anytime d...
# 8                                                473
# 9                                                613

# %% [markdown]
# The URLs do load properly, but do not result in dataframes useful for analysis using the read_excel function defaults. The read_excel function defaults treat the first line as column labels, but these files contain ancillary data on the
# first few lines, with the labels actually on line 8 (offset 7) and the data starting on line 9.
#
# The read_excel function does have a parameter to specify column labels are on a specific line. Use that option to see what difference it makes on the dataframe produced. Use just the first URL for brevity.

# %%
url = datafile_list[0].get('url')
df = pd.read_excel(url,header=8)
df.head(10)
# Out:
#                         State  Number of reported LEAs1  \
# 0                     Alabama                     143.0
# 1                      Alaska                      54.0
# 2              American Samoa                       1.0
# 3                     Arizona                     638.0
# 4                    Arkansas                     263.0
# 5  Bureau of Indian Education                     174.0
# 6                  California                    1482.0
# 7                    Colorado                      68.0
# 8                 Connecticut                     162.0
# 9                    Delaware                      43.0
#
#   Number of children who received CEIS during SY 2020-21  \
# 0                                                  +
# 1                                                248
# 2                                                  +
# 3                                                890
# 4                                                100
# 5                                               1126
# 6                                              32834
# 7                                                  0
# 8                                                266
# 9                                               8905
#
#   Number of children who received CEIS anytime during SY 2018-19, 2019-20, 2020-21 and received special education and related services during SY 2020-21
# 0                                                  +
# 1                                                543
# 2                                                  +
# 3                                               3730
# 4                                                388
# 5                                                 99
# 6                                              29569
# 7                                                 29
# 8                                                 33
# 9                                               1950

# %% [markdown]
# The resulting dataframe has better labels, but is still not ideal for combining with the other datasets. To illustrate the issue, load a second URL into another dataframe.

# %%
url2 = datafile_list[1].get('url')
df2 = pd.read_excel(url2,header=8)
print('Second dataset.')
df2.head(10)
# Out:
# Second dataset.
#                         State  Number of reported LEAs1  \
# 0                     Alabama                     142.0
# 1                      Alaska                      54.0
# 2              American Samoa                       1.0
# 3                     Arizona                     611.0
# 4                    Arkansas                     268.0
# 5  Bureau of Indian Education                     174.0
# 6                  California                    1402.0
# 7                    Colorado                      67.0
# 8                 Connecticut                     162.0
# 9                    Delaware                      42.0
#
#   Number of children who received CEIS during SY 2019-20  \
# 0                                                  +
# 1                                                452
# 2                                                  +
# 3                                                627
# 4                                                807
# 5                                               1329
# 6                                              42578
# 7                                                 81
# 8                                                125
# 9                                              12334
#
#   Number of children who received CEIS anytime during SY 2017-18, 2018-19, 2019-20 and received special education and related services during SY 2019-20
# 0                                                  +
# 1                                                694
# 2                                                  +
# 3                                                410
# 4                                                141
# 5                                                160
# 6                                              22469
# 7                                                 52
# 8                                                 19
# 9                                               1445

# %% [markdown]
# Combine the two dataframes.

# %%
cdf = pd.concat([df,df2])
print('Combined dataset.')
cdf.head(10)
# Out:
# Combined dataset.
#                         State  Number of reported LEAs1  \
# 0                     Alabama                     143.0
# 1                      Alaska                      54.0
# 2              American Samoa                       1.0
# 3                     Arizona                     638.0
# 4                    Arkansas                     263.0
# 5  Bureau of Indian Education                     174.0
# 6                  California                    1482.0
# 7                    Colorado                      68.0
# 8                 Connecticut                     162.0
# 9                    Delaware                      43.0
#
#   Number of children who received CEIS during SY 2020-21  \
# 0                                                  +
# 1                                                248
# 2                                                  +
# 3                                                890
# 4                                                100
# 5                                               1126
# 6                                              32834
# 7                                                  0
# 8                                                266
# 9                                               8905
#
#   Number of children who received CEIS anytime during SY 2018-19, 2019-20, 2020-21 and received special education and related services during SY 2020-21  \
# 0                                                  +
# 1                                                543
# 2                                                  +
# 3                                               3730
# 4                                                388
# 5                                                 99
# 6                                              29569
# 7                                                 29
# 8                                                 33
# 9                                               1950
#
#   Number of children who received CEIS during SY 2019-20  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Number of children who received CEIS anytime during SY 2017-18, 2018-19, 2019-20 and received special education and related services during SY 2019-20
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# The dataframe resulting from concatenating the two datasets with default parameters retains only the LEA count from the first dataframe passed to the concat function, since the column label is "Number of LEAs reported" in both source dataframes. There are ways to avoid that with different pandas functions or concat parameters, but the result still loses the information of which school year corresponds to a given LEA count. That's because the school year is embedded in the column name for some of the data values, such as "Number of children who received CEIS during SY 2020-2021", but not the column labeled "Number of LEAs reported".
#
# One way to solve that issue is to explicitly add the school year as another column in each dataframe. The school year is explicitly listed in row 1, column 1, but that row is skipped if the header parameter is used. So, instead of specifying a header parameter value and letting read_excel assign column labels based on the values in the specified row, use the names parameter to assign the column labels. The row containing the school year will thus still be read, and the school year can be extracted and added to the dataframe as an additional column.

# %%
# Read the entire spreadsheet, explicitly assigning column labels.
url1 = datafile_list[0].get('url')
df1 = pd.read_excel(url1, names=['State','Number LEAs','Number receiving CEIS',
                                 'Number receiving CEIS and special education services'])
# Extract the school year from the second row of the resulting dataframe.
school_year = df1.iloc[0].iloc[1]
print(f'School year: {school_year}')

# Add another column containing the extracted school year.
df1['School year'] = school_year

df1.head(10)
# Out:
# School year: 2020-21
#                                                State  \
# 0                                        School Year
# 1                                         Collection
# 2                                          Developed
# 3                                            Revised
# 4                                                NaN
# 5  Number of children who received CEIS anytime i...
# 6                                                NaN
# 7                                              State
# 8                                            Alabama
# 9                                             Alaska
#
#                                          Number LEAs  \
# 0                                            2020-21
# 1  Part B Maintenance of Effort Reduction and Coo...
# 2                                2022-11-01 00:00:00
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                           Number of reported LEAs1
# 8                                                143
# 9                                                 54
#
#                                Number receiving CEIS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Number of children who received CEIS during SY...
# 8                                                  +
# 9                                                248
#
#   Number receiving CEIS and special education services School year
# 0                                                NaN       2020-21
# 1                                                NaN       2020-21
# 2                                                NaN       2020-21
# 3                                                NaN       2020-21
# 4                                                NaN       2020-21
# 5                                                NaN       2020-21
# 6                                                NaN       2020-21
# 7  Number of children who received CEIS anytime d...       2020-21
# 8                                                  +       2020-21
# 9                                                543       2020-21

# %% [markdown]
# The first few rows are no longer useful, so they can be removed from the dataframe.

# %%
df1.drop(range(8),inplace=True)
df1.head(10)
# Out:
#                          State Number LEAs Number receiving CEIS  \
# 8                      Alabama         143                     +
# 9                       Alaska          54                   248
# 10              American Samoa           1                     +
# 11                     Arizona         638                   890
# 12                    Arkansas         263                   100
# 13  Bureau of Indian Education         174                  1126
# 14                  California        1482                 32834
# 15                    Colorado          68                     0
# 16                 Connecticut         162                   266
# 17                    Delaware          43                  8905
#
#    Number receiving CEIS and special education services School year
# 8                                                   +       2020-21
# 9                                                 543       2020-21
# 10                                                  +       2020-21
# 11                                               3730       2020-21
# 12                                                388       2020-21
# 13                                                 99       2020-21
# 14                                              29569       2020-21
# 15                                                 29       2020-21
# 16                                                 33       2020-21
# 17                                               1950       2020-21

# %% [markdown]
# Note the data files use a convention of storing a "+" in each cell for which data was not reported. Translate those "+" values into "not a number" (NaN) values in the dataframe to make analysis easier.

# %%
# Use the to_numeric function with a parameter of errors='coerce' to compensate
# for any non-numeric strings encoded in the data.
df1['Number LEAs'] = pd.to_numeric(df1['Number LEAs'], errors='coerce')
df1['Number receiving CEIS'] = pd.to_numeric(df1['Number receiving CEIS'], errors='coerce')
df1['Number receiving CEIS and special education services'] = pd.to_numeric(df1['Number receiving CEIS and special education services'], errors='coerce')
df1.head()
# Out:
#              State  Number LEAs  Number receiving CEIS  \
# 8          Alabama        143.0                    NaN
# 9           Alaska         54.0                  248.0
# 10  American Samoa          1.0                    NaN
# 11         Arizona        638.0                  890.0
# 12        Arkansas        263.0                  100.0
#
#     Number receiving CEIS and special education services School year
# 8                                                 NaN        2020-21
# 9                                               543.0        2020-21
# 10                                                NaN        2020-21
# 11                                             3730.0        2020-21
# 12                                              388.0        2020-21

# %% [markdown]
# Perform the same operations on the second data file.

# %%
url2 = datafile_list[1].get('url')
df2 = pd.read_excel(url2, names=['State','Number LEAs','Number receiving CEIS',
                                 'Number receiving CEIS and special education services'])

school_year = df2.iloc[0].iloc[1]

df2['School year'] = school_year
df2.drop(range(8), inplace=True)
df2['Number LEAs'] = pd.to_numeric(df2['Number LEAs'],errors='coerce')
df2['Number receiving CEIS'] = pd.to_numeric(df2['Number receiving CEIS'],errors='coerce')
df2['Number receiving CEIS and special education services'] = pd.to_numeric(df2['Number receiving CEIS and special education services'],errors='coerce')

df2.head(10)
# Out:
#                          State  Number LEAs  Number receiving CEIS  \
# 8                      Alabama        142.0                    NaN
# 9                       Alaska         54.0                  452.0
# 10              American Samoa          1.0                    NaN
# 11                     Arizona        611.0                  627.0
# 12                    Arkansas        268.0                  807.0
# 13  Bureau of Indian Education        174.0                 1329.0
# 14                  California       1402.0                42578.0
# 15                    Colorado         67.0                   81.0
# 16                 Connecticut        162.0                  125.0
# 17                    Delaware         42.0                12334.0
#
#     Number receiving CEIS and special education services School year
# 8                                                 NaN        2019-20
# 9                                               694.0        2019-20
# 10                                                NaN        2019-20
# 11                                              410.0        2019-20
# 12                                              141.0        2019-20
# 13                                              160.0        2019-20
# 14                                            22469.0        2019-20
# 15                                               52.0        2019-20
# 16                                               19.0        2019-20
# 17                                             1445.0        2019-20

# %% [markdown]
# Concatenate the two dataframes, explicitly resetting the index in the result.

# %%
cdf = pd.concat([df1,df2],ignore_index=True)

# Show all the rows in the combined dataframe for the State of Alabama.
cdf.loc[cdf['State'] == 'Alabama']
# Out:
#       State  Number LEAs  Number receiving CEIS  \
# 0   Alabama        143.0                    NaN
# 77  Alabama        142.0                    NaN
#
#     Number receiving CEIS and special education services School year
# 0                                                 NaN        2020-21
# 77                                                NaN        2019-20

# %% [markdown]
# Since all the column names match in both dataframes, but the indices in the source dataframes was ignored, the resulting dataframe has a row for each row in each source dataframe. The added "School year" column identifies which school year is applicable to each row. Performing the same operations on all the datafiles will result in a combined dataframe that can be used for trend analysis.
#
# Write a function to perform the common operations on each datafile.

# %%
def prepare_datafile(url):
    df = pd.read_excel(url,names=['State','Number LEAs','Number receiving CEIS',
                                  'Number receiving CEIS and special education services'])
    school_year = df.iloc[0].iloc[1]
    df['School year'] = school_year

    df.drop(range(8),inplace=True)

    df['Number LEAs'] = pd.to_numeric(df['Number LEAs'],errors='coerce')
    df['Number receiving CEIS'] = pd.to_numeric(df['Number receiving CEIS'],errors='coerce')
    df['Number receiving CEIS and special education services'] = pd.to_numeric(df['Number receiving CEIS and special education services'],errors='coerce')

    return df

# %% [markdown]
# Loop over all the datafiles, preparing them using the above function, and combining the result.

# %%
cdf = None
for datafile in datafile_list:
    url = datafile.get('url',None)
    if url is not None:
        # Ensure the url actually looks like an Excel spreadsheet.
        if url.endswith('.xlsx'):
            df = prepare_datafile(url)
            if cdf is None:
                cdf = df
            else:
                cdf = pd.concat([cdf,df],ignore_index=True)

# Check all the values for the State of Alabama.
cdf.loc[cdf['State'] == 'Alabama']
# Out:
#        State  Number LEAs  Number receiving CEIS  \
# 0    Alabama        143.0                    NaN
# 77   Alabama        142.0                    NaN
# 154  Alabama        139.0                    NaN
# 229  Alabama        138.0                   50.0
# 304  Alabama        137.0                  933.0
# 379  Alabama        137.0                  802.0
# 454  Alabama        136.0                  866.0
# 529  Alabama        135.0                 2399.0
#
#      Number receiving CEIS and special education services School year
# 0                                                  NaN        2020-21
# 77                                                 NaN        2019-20
# 154                                                NaN        2018-19
# 229                                             1768.0        2017-18
# 304                                              149.0        2016-17
# 379                                              178.0        2015-16
# 454                                              575.0        2014-15
# 529                                              473.0        2013-14

# %% [markdown]
# To illustrate the type of analysis that can be done on the combined dataset, aggregate the child counts by school year.

# %%
gdf = cdf.groupby(['School year']).agg({'Number receiving CEIS':'sum',
                                        'Number receiving CEIS and special education services':'sum'})
gdf
# Out:
#              Number receiving CEIS  \
# School year
# 2013-14                  1577168.0
# 2014-15                  1470812.0
# 2015-16                  1412122.0
# 2016-17                  1534814.0
# 2017-18                  1311272.0
# 2018-19                   859082.0
# 2019-20                   803532.0
# 2020-21                   629262.0
#
#              Number receiving CEIS and special education services
# School year
# 2013-14                                               239170.0
# 2014-15                                               277636.0
# 2015-16                                               230986.0
# 2016-17                                               248942.0
# 2017-18                                               230268.0
# 2018-19                                               131960.0
# 2019-20                                               181508.0
# 2020-21                                               160156.0
